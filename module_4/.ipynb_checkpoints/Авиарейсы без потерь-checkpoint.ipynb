# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind
from statsmodels.stats import weightstats

pd.set_option('display.max_rows', 50)  # показывать больше строк
pd.set_option('display.max_columns', 50)  # показывать больше колонок
colors = ['g', 'maroon']

# %%
data = pd.read_csv('final_query.csv')

# %%
data.sample()
# Out:
#    flight_id city_departure city_arrival           model  range  \
# 0     136119          Anapa       Moscow  Boeing 737-300   4200
#
#    total_cost_of_tickets  flight_duration_minutes     scheduled_departure  \
# 0              1653000.0                      101  2017-01-03 10:05:00+00
#
#    number_of_tickets  n_busines  common_n_b_class_seats  n_economy  \
# 0                113       11.0                      12      102.0
#
#    common_n_e_class_seats flight_delay
# 0                     118     00:03:00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   flight_id                127 non-null    int64
#  1   city_departure           127 non-null    object
#  2   city_arrival             127 non-null    object
#  3   model                    127 non-null    object
#  4   range                    127 non-null    int64
#  5   total_cost_of_tickets    118 non-null    float64
#  6   flight_duration_minutes  127 non-null    int64
#  7   scheduled_departure      127 non-null    object
#  8   number_of_tickets        127 non-null    int64
#  9   n_busines                118 non-null    float64
#  10  common_n_b_class_seats   127 non-null    int64
#  11  n_economy                118 non-null    float64
#  12  common_n_e_class_seats   127 non-null    int64
#  13  flight_delay             127 non-null    object
# ...

# %% [markdown]
# Имеется 9 пустых значений в колонке `total_cost_of_tickets` - общая стоимость проданных билетов, значит нет возможности посчитать прибыль для этих рейсов. В колонках `n_busines` - количество проданных билетов в бизнесс-класс и `n_economy` - количество проданных билетов в эконом-класс тоже по 9 пропусков. Это закономерно, поскольку все эти три колонки извлекались из одной и той-же колонки в базе данных.
#
# Посмотрим, что это за рейсы.

# %%
data[data.total_cost_of_tickets.isna() == True]
# Out:
#     flight_id city_departure  city_arrival           model  range  \
# 59     136511          Anapa  Novokuznetsk  Boeing 737-300   4200
# 60     136513          Anapa  Novokuznetsk  Boeing 737-300   4200
# 61     136514          Anapa  Novokuznetsk  Boeing 737-300   4200
# 62     136523          Anapa  Novokuznetsk  Boeing 737-300   4200
# 63     136540          Anapa  Novokuznetsk  Boeing 737-300   4200
# 64     136544          Anapa  Novokuznetsk  Boeing 737-300   4200
# 65     136546          Anapa  Novokuznetsk  Boeing 737-300   4200
# 66     136560          Anapa  Novokuznetsk  Boeing 737-300   4200
# 67     136567          Anapa  Novokuznetsk  Boeing 737-300   4200
#
#     total_cost_of_tickets  flight_duration_minutes     scheduled_departure  \
# 59                    NaN                      310  2017-02-21 06:10:00+00
# 60                    NaN                      310  2017-02-28 06:10:00+00
# 61                    NaN                      299  2017-02-07 06:10:00+00
# ...

# %% [markdown]
# Все пропущенные значения для города Новокузнецк.

# %% [markdown]
# Есть-ли вообще данные по ценам за билеты для Новокузнецка?

# %%
display(len(data[data['city_arrival'] == 'Novokuznetsk']))
data[data['city_arrival'] == 'Novokuznetsk']
# Out:
# 9
#     flight_id city_departure  city_arrival           model  range  \
# 59     136511          Anapa  Novokuznetsk  Boeing 737-300   4200
# 60     136513          Anapa  Novokuznetsk  Boeing 737-300   4200
# 61     136514          Anapa  Novokuznetsk  Boeing 737-300   4200
# 62     136523          Anapa  Novokuznetsk  Boeing 737-300   4200
# 63     136540          Anapa  Novokuznetsk  Boeing 737-300   4200
# 64     136544          Anapa  Novokuznetsk  Boeing 737-300   4200
# 65     136546          Anapa  Novokuznetsk  Boeing 737-300   4200
# 66     136560          Anapa  Novokuznetsk  Boeing 737-300   4200
# 67     136567          Anapa  Novokuznetsk  Boeing 737-300   4200
#
#     total_cost_of_tickets  flight_duration_minutes     scheduled_departure  \
# 59                    NaN                      310  2017-02-21 06:10:00+00
# 60                    NaN                      310  2017-02-28 06:10:00+00
# 61                    NaN                      299  2017-02-07 06:10:00+00
# ...

# %% [markdown]
# Для всех девяти рейсов на Новокузнецк нет данных об общей стоимости проданных билетов.
#
# Следует исключить из анализа эти данные. Очень жаль, нет возможности оценить целое направление.

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 0 to 126
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   flight_id                118 non-null    int64
#  1   city_departure           118 non-null    object
#  2   city_arrival             118 non-null    object
#  3   model                    118 non-null    object
#  4   range                    118 non-null    int64
#  5   total_cost_of_tickets    118 non-null    float64
#  6   flight_duration_minutes  118 non-null    int64
#  7   scheduled_departure      118 non-null    object
#  8   number_of_tickets        118 non-null    int64
#  9   n_busines                118 non-null    float64
#  10  common_n_b_class_seats   118 non-null    int64
#  11  n_economy                118 non-null    float64
#  12  common_n_e_class_seats   118 non-null    int64
#  13  flight_delay             118 non-null    object
# ...

# %% [markdown]
# Пропуски удалены.
#
# Колонки `scheduled_departure` и `flight_delay` имеют строковый формат переведём их в дату и время соответственно.

# %%
data['scheduled_departure'] = pd.to_datetime(data['scheduled_departure'])
data['flight_delay'] = pd.to_timedelta(data['flight_delay'])
data.flight_delay = data.flight_delay.dt.seconds # timedelta to seconds
data.flight_delay = data.flight_delay / 60       # seconds to minutes

# %% [markdown]
# ### flight_id
# Идентификационный номер рейса. Всего, за зиму 2017 совершено 127 рейсов из Анапы, из них 9 в Новокузнецк, по которым нет данных о стоимости проданных билетов. Все дальнейшие исследования будут проводиться с оставшимися 118 рейсами.

# %% [markdown]
# ### city_departure
# Город вылета по условиям задачи один - Анапа.
#
# ### city_arrival
# Город прилёта. Направление.

# %%
data.city_arrival.unique()
# Out:
# array(['Moscow', 'Belgorod'], dtype=object)

# %% [markdown]
# Итак, у нас имеется два направления, __Москва__ и __Белгород__.

# %% [markdown]
# ## model
# Модель самолёта.

# %%
data.model.unique()
# Out:
# array(['Boeing 737-300', 'Sukhoi Superjet-100'], dtype=object)

# %% [markdown]
# На указанных направлениях используются две модели самолётов: __Boeing 737-300__ и __Sukhoi Superjet-100__.

# %% [markdown]
# Посмотрим, как связаны между собой модель самолёта и направление.

# %%
data[data.city_arrival == 'Moscow'].model.unique()
# Out:
# array(['Boeing 737-300'], dtype=object)

# %% [markdown]
# В Москву из Анапы зимой летают только Боинги.

# %%
data[data.city_arrival == 'Belgorod'].model.unique()
# Out:
# array(['Sukhoi Superjet-100'], dtype=object)

# %% [markdown]
# А в Белгород только самолёты Сухого.
# М.б. Сухой не может долететь до Москвы? Не хватает дальности полёта.
# Проверим.

# %% [markdown]
# ### range
# Максимальная дальность полёта.

# %%
Sukhoi = data[data.model == 'Sukhoi Superjet-100'].range.unique()
Boeing = data[data.model == 'Boeing 737-300'].range.unique()
print(
    f'Максимальная дальность полёта для Boeing 737-300 составляет {Boeing[0]} км.')
print(
    f'Максимальная дальность полёта для Sukhoi Superjet-100 составляет {Sukhoi[0]} км.')
# Out:
# Максимальная дальность полёта для Boeing 737-300 составляет 4200 км.
# Максимальная дальность полёта для Sukhoi Superjet-100 составляет 3000 км.

# %% [markdown]
# Расстояние от аэропорта Анапы до аэропорта Шереметьево по-прямой 1220 км., в обход Украины 1360 км.
# Запаса дальности полёта Сухого хватило-бы слетать до Москвы и обратно, гипотеза о нехватки дальности оплёта отвергается.
# Расстояние от Анапы до Белгорода в обход Украины 960 км, по прямой 630.

# %% [markdown]
# ### total_cost_of_tickets
# Полная стоимость проданных билелетов на рейсе.
# ### flight_duration_minutes
# Длительность полёта в минутах.
#
# Из этиз двух колонок вычислим прибыль `revenue` введя дополнительные данные.

# %%
def month_to_price(month):
    '''take month, return fuel price'''
    if month == 1:
        return 35.59  # price rub/kg

    elif month == 2:
        return 33.39  # price rub/kg


def consumption(model):
    '''take aircraft model, return fuel consumption'''
    if model == 'Sukhoi Superjet-100':
        return 28.333333333333332  # fuel consumption l/m

    elif model == 'Boeing 737-300':
        return 43.333333333333336  # fuel consumption l/m

# %%
data['fuel_price'] = data.scheduled_departure.dt.month.apply(
    month_to_price)  # cost of one liter of fuel
data['fuel_consumption'] = data.model.apply(
    consumption)  # fuel consumption, liter/minute
data['fuel_costs'] = data.flight_duration_minutes * data.fuel_consumption * \
    data.fuel_price  # the price of the spent fuel in rubles
data['revenue'] = data.total_cost_of_tickets - data.fuel_costs

# %%
data.head()
# Out:
#    flight_id city_departure city_arrival           model  range  \
# 0     136119          Anapa       Moscow  Boeing 737-300   4200
# 1     136120          Anapa       Moscow  Boeing 737-300   4200
# 2     136122          Anapa       Moscow  Boeing 737-300   4200
# 3     136130          Anapa       Moscow  Boeing 737-300   4200
# 4     136131          Anapa       Moscow  Boeing 737-300   4200
#
#    total_cost_of_tickets  flight_duration_minutes       scheduled_departure  \
# 0              1653000.0                      101 2017-01-03 10:05:00+00:00
# 1              1605400.0                       99 2017-02-24 10:05:00+00:00
# 2              1431000.0                      100 2017-01-08 10:05:00+00:00
# 3              1556600.0                       99 2017-02-13 10:05:00+00:00
# 4              1812800.0                       99 2017-01-28 10:05:00+00:00
#
#    number_of_tickets  n_busines  common_n_b_class_seats  n_economy  \
# ...

# %% [markdown]
# Данные о ценах на топливо взяты с [сайта поставщика топлива](http://www.bato.aero/) аэропорта города Анапа.
# Цена топлива в январе 35.59 тысячи рублей за тонну или рублей за кг и 33.39 тысячи рублей за тонну или рублей за кг в феврале.
#
# Потребление топлива 2600 кг/час для Boeing 737-300 взято [отсюда](https://www.airlines-inform.ru/commercial-aircraft/boeing-737-300.html).
# Расход топлива л/мин таким образом составил 43.333333333333336.
#
# Потребление топлива 1700 кг/час для Sukhoi Superjet-100 взято [отсюда](http://superjet.wikidot.com/wiki:rashod-topliva).   Расход топлива л/мин таким образом составил 28.333333333333332.
#
# Стоимость потраченного топлива расчитана как произведение длительности полёта в минутах на расход топлива в л/мин, на цену за литр топлива.
# Прибыль расчитана как стоимость проданных билетов за вычетом цены потраченного топлива.

# %%
len(data[data['revenue'] < 0]) # number of unprofitable flights
# Out:
# 0

# %% [markdown]
# Получается что при текущем расчёте прибыли в датасете нет откровенно убыточных рейсов.
# Однако на [указанном сайте](http://www.bato.aero/), есть информация о тарифах на услуги для клиентов аэропортов, из которой следует, что помимо цены за топливо, с клиемтов взымается плата за заправку воздушного судна и за хранение топлива.
#
# Тариф за обеспечение заправки воздушного судна авиационным топливом (Анапа) Руб./т 1752,00.
# Тариф за хранение авиационного топлива (Анапа) Руб./т 1913,00.
#
# Думаю стоит учесть эти данные при расчёте затрат для более точного определения прибыли.
# Однако тут есть один нюанс. В бак самолёта заправляется топлива больше, чем он тратит за полёт. Значит мы не можем учесть полную цену по этим дополнительным тарифам. За неимением другой информации оставим этот момент как есть, предположив, что непотраченное топливо сохраняется для следующего рейса, и за его заправку и хранение не приходится платить дважды.
#
# Следует перерасчитать колонку `fuel_costs` следующим образом, как сумму:
# * цена затраченного топлива = затраченное топливо (произведение длительности полёта (минуты) и расхода топлива (литры/мин)) умножить на цену за литр;
# * затраченное топливо в килограммах перевести в тонны, затем умножить на тариф за обеспечение заправки воздушного судна авиационным топливом;
# * затраченное топливо в килограммах перевести в тонны, затем умножить на тариф за хранение авиационного топлива.

# %%
# the price of the spent fuel in rubles
data['fuel_costs'] = (data.flight_duration_minutes *
                      data.fuel_consumption * data.fuel_price) + \
                     (data.flight_duration_minutes * 
                      data.fuel_consumption * 1752 / 1000) +\
                     (data.flight_duration_minutes * 
                      data.fuel_consumption * 1913 / 1000)
data['revenue'] = data.total_cost_of_tickets - data.fuel_costs

# %%
data.head()
# Out:
#    flight_id city_departure city_arrival           model  range  \
# 0     136119          Anapa       Moscow  Boeing 737-300   4200
# 1     136120          Anapa       Moscow  Boeing 737-300   4200
# 2     136122          Anapa       Moscow  Boeing 737-300   4200
# 3     136130          Anapa       Moscow  Boeing 737-300   4200
# 4     136131          Anapa       Moscow  Boeing 737-300   4200
#
#    total_cost_of_tickets  flight_duration_minutes       scheduled_departure  \
# 0              1653000.0                      101 2017-01-03 10:05:00+00:00
# 1              1605400.0                       99 2017-02-24 10:05:00+00:00
# 2              1431000.0                      100 2017-01-08 10:05:00+00:00
# 3              1556600.0                       99 2017-02-13 10:05:00+00:00
# 4              1812800.0                       99 2017-01-28 10:05:00+00:00
#
#    number_of_tickets  n_busines  common_n_b_class_seats  n_economy  \
# ...

# %%
len(data[data['revenue'] < 0]) # number of unprofitable flights
# Out:
# 0

# %% [markdown]
# Опять-же при учёте дополнительных трат на топливо, в датасете нет откровенно убыточных рейсов.

# %% [markdown]
# Ключевая переменная - прибыль.
#
# Посмотрим, с какими признаками она линейно зависима.

# %%
sns.heatmap(data.corr(), annot=True)
plt.gcf().set_size_inches(12, 12)

# %% [markdown]
# Как видно из тепловой карты, довольно много признаков линейно влияют на прибыль.
# Рассмотрим их всех детальнее.
#
# Но для начала посмотрим на распределение самой прибыли.

# %%
plt.figure(figsize=(15, 5))
plt.subplot(121)

sns.distplot(data['revenue'].values, bins=25, color=colors[0], kde=False)
plt.title('Revenue Distribution', fontsize=15)
plt.xlabel('revenue')
plt.ylabel('quantity')

plt.subplot(122)
sns.boxplot(data['revenue'].values, color=colors[1])
plt.title('Revenue Distribution', fontsize=15)
plt.xlabel('revenue')
plt.show()

# %% [markdown]
# Видно, что вся выборка делится на две группы по распределению.
# Нужно попробовать разбить распределение по направлениям или моделям самолётов, что в данном случае тождественно.

# %% [markdown]
# Посмотрим распределение прибыли по городам.

# %%
for city in (data['city_arrival'].value_counts()).index:
    plt.figure(figsize=(15, 5))
    plt.subplot(121)
    section = data[data['city_arrival'] == city]['revenue']
    sns.distplot(section.values, bins=25, color=colors[0], kde=False)
    plt.title(f'Revenue Distribution for {city}', fontsize=15)
    plt.xlabel('revenue')
    plt.ylabel('quantity')

    plt.subplot(122)
    sns.boxplot(section.values, color=colors[1])
    plt.title(f'Revenue Distribution for {city}', fontsize=15)
    plt.xlabel('revenue')
    plt.show()

# %%
for model in (data['model'].value_counts()).index:
    plt.figure(figsize=(15, 5))
    plt.subplot(121)
    section = data[data['model'] == model]['revenue']
    sns.distplot(section.values, bins=25, color=colors[0], kde=False)
    plt.title(f'Revenue Distribution for {model}', fontsize=15)
    plt.xlabel('revenue')
    plt.ylabel('quantity')

    plt.subplot(122)
    sns.boxplot(section.values, color=colors[1])
    plt.title(f'Revenue Distribution for {model}', fontsize=15)
    plt.xlabel('revenue')
    plt.show()

# %% [markdown]
# Несмотря на то, что Сухой потребляет меньше горючего чем Боинг, а значит и издержки у Боинга больше, прибыль при использовании Боингов выше.
# Интересно почему? Ответ на этот вопрос поищем в дальнейшем анализе датасета.

# %% [markdown]
# ### scheduled_departure
# Запланированные дата и время вылета.
#
# Добавим столбец дни недели `day_of_week`.

# %%
data['day_of_week'] = data.scheduled_departure.dt.dayofweek

def days(day):
    '''take day code as int, return day code string'''
    if day == 0: return 'Monday'
    elif day == 1: return 'Thuesday'
    elif day == 2: return 'Wednesday'
    elif day == 3: return 'Thursday'
    elif day == 4: return 'Friday'
    elif day == 5: return 'Saturday'
    elif day == 6: return 'Sunday'


data['day_of_week'] = data.day_of_week.apply(days)

# %% [markdown]
# Посмотрим распределение прибыли относительно дней недели.

# %%
for model in (data['model'].value_counts()).index: 
    for day in (data['day_of_week'].value_counts()).index:
        plt.figure(figsize=(15, 5))
        plt.subplot(121)
        section = data[(data['model'] == model) & (data['day_of_week'] == day)]['revenue']
        sns.distplot(section.values, bins=25, color=colors[0], kde=False)
        plt.title(f'Revenue Distribution for {model} on {day}s', fontsize=10)
        plt.xlabel('revenue')
        plt.ylabel('quantity')

        plt.subplot(122)
        sns.boxplot(section.values, color=colors[1])
        plt.title(f'Revenue Distribution for {model} on {day}s', fontsize=10)
        plt.xlabel('revenue')
        plt.show()

# %% [markdown]
# Не могу ничего определённого сказать про распределение по дням недели, кроме того, что рейсы с минимальной прибылью равномерно распределены по дням недели.
#
# Добавим столбец месяц, посмотрим распределение прибыли по месяцам.

# %%
data['month'] = data.scheduled_departure.dt.month
data['month'].unique()
# Out:
# array([1, 2])

# %% [markdown]
# В датасете из всей зимы 2017 года присутствуют только даные за январь и февраль, декабрь отсутствует.
# Посмотрим распределение прибыли в ти два месяца, с учётом модели самолёта.

# %%
for model in (data['model'].value_counts()).index: 
    for month in (data['month'].value_counts()).index:
        plt.figure(figsize=(15, 5))
        plt.subplot(121)
        section = data[(data['model'] == model) & (data['month'] == month)]['revenue']
        sns.distplot(section.values, bins=25, color=colors[0], kde=False)
        if month == 1:
            month = "January"
        else:
            month = "February"
        plt.title(f'Revenue Distribution for {model} in {month}', fontsize=14)
        plt.xlabel('revenue')
        plt.ylabel('quantity')

        plt.subplot(122)
        sns.boxplot(section.values, color=colors[1])
        plt.title(f'Revenue Distribution for {model} in {month}', fontsize=14)
        plt.xlabel('revenue')
        plt.show()

# %% [markdown]
# Картина схожая с предыдущей, вывод тоже.
#
# Посмотрим, что у нас ещё есть в нашем арсенале.
#
# ### number_of_tickets
# Количество проданных билетов.

# %%
su = data.loc[data.model == 'Sukhoi Superjet-100',['revenue', 'number_of_tickets']]
sns.heatmap(su.corr(), annot=True)
plt.title('Sukhoi Superjet-100', fontsize=15)
plt.gcf().set_size_inches(4, 4)
sns.jointplot(data=su, y="number_of_tickets", x="revenue", color=colors[0])
plt.show()

# %%
Boeing = data.loc[data.model == 'Boeing 737-300',['revenue', 'number_of_tickets']]
sns.heatmap(Boeing.corr(), annot=True)
plt.title('Boeing 737-300', fontsize=15)
plt.gcf().set_size_inches(4, 4)
sns.jointplot(data=Boeing, y="number_of_tickets", x="revenue", color=colors[1])
plt.show()

# %% [markdown]
# Как можно увидеть из тепловых карт, зависимость заполнения салона и прибыли прямая, что логично. И не зависит от направления полётов / модели самолёта.

# %% [markdown]
# ### n_busines
# Количество проданных на рейс билетов бизнесс класса.
#
# ### common_n_b_class_seats
# Общее количество мест в бизнесс классе на рейсе.
#
# ### n_economy
# Количество проданных на рейс билетов эконом класса.
#
# ### common_n_e_class_seats
# Общее количество мест в эконом классе на рейсе.
#
# Из этой информации можно посмотреть заполняемость салона по классам и влияние класса комфорта на прибыль.
# Для начала ещё раз посмотри корреляцию этих переменной с целевой.

# %%
part = data.loc[:, ['revenue', 'n_busines', 'common_n_b_class_seats',
                  'n_economy', 'common_n_e_class_seats']]
sns.heatmap(part.corr(), annot=True)
plt.title('Pirson', fontsize=15)
plt.gcf().set_size_inches(5, 5)

# %% [markdown]
# Общее количество мест в эконом классе напрямую влияет на размер прибыли.
# Однако общее количество мест в бизнес классе вообще не учитываетсякорреляцией.
#
# Возможно общее количество мест в бизнес классе не меняется в выборке, тогда как количество мест в эконом классе меняется.
# Так-же стоит отметить, что количество проданных билетов бизнес класса слабо влияют на прибыль. Вероятно такая картина наблюдается в следствие того, что общее количество мест в бизнес классе гораздо меньше, чем количество мест в эконом классе, а так-же возможно, в следствие их более равномерного наполнения, чем мест в эконом классе.

# %%
data.common_n_b_class_seats.unique()
# Out:
# array([12])

# %%
data.common_n_e_class_seats.unique()
# Out:
# array([118,  85])

# %%
data[data.model == 'Boeing 737-300'].common_n_e_class_seats.unique()
# Out:
# array([118])

# %% [markdown]
# Значит гипотеза подтверждается, количество мест бизнес класса в данных моделях самолётов одинаковое, а количество мест в эконом классе у Боинга больше, чем у Сухого, 118, против 85.
#
# Теперь посмотрим заполнение этих мест.

# %%
data['econom_filling'] = data.n_economy / data.common_n_e_class_seats
data['busines_filling'] = data.n_busines / data.common_n_b_class_seats

# %%
for model in (data['model'].value_counts()).index:
    plt.figure(figsize=(15, 5))
    plt.subplot(121)    
    section = data[data['model'] == model]['econom_filling']
    display(model, section.value_counts())
    sns.distplot(section.values, bins=20, color=colors[0], kde=False)
    plt.title(f'econom_filling Distribution for {model}', fontsize=15)
    plt.xlabel('econom_filling')
    plt.ylabel('quantity')
    plt.subplot(122)
    sns.boxplot(section.values, color=colors[1])
    plt.title(f'econom_filling Distribution for {model}', fontsize=15)
    plt.xlabel('econom_filling')
    plt.show()
# Out:
# 'Sukhoi Superjet-100'
# 1.000000    18
# 0.988235     9
# 0.905882     4
# 0.858824     4
# 0.894118     3
# 0.976471     3
# 0.964706     3
# 0.917647     3
# 0.823529     3
# 0.835294     1
# 0.882353     1
# 0.847059     1
# 0.705882     1
# 0.811765     1
# 0.800000     1
# 0.941176     1
# 0.776471     1
# 0.635294     1
# Name: econom_filling, dtype: int64
# 'Boeing 737-300'
# 0.830508    7
# 0.881356    4
# 0.915254    4
# 0.855932    3
# 0.864407    3
# 0.822034    3
# 0.991525    3
# 1.000000    3
# 0.949153    3
# 0.847458    3
# 0.923729    2
# 0.788136    2
# 0.838983    2
# 0.796610    2
# 0.872881    2
# 0.771186    1
# 0.906780    1
# 0.728814    1
# 0.813559    1
# 0.957627    1
# 0.762712    1
# 0.932203    1
# 0.737288    1
# 0.889831    1
# 0.898305    1
# 0.779661    1
# 0.754237    1
# 0.940678    1
# Name: econom_filling, dtype: int64

# %%
for model in (data['model'].value_counts()).index:
    plt.figure(figsize=(15, 5))
    plt.subplot(121)
    section = data[data['model'] == model]['busines_filling']
    display(model, section.value_counts())
    sns.distplot(section.values, bins=7, color=colors[0], kde=False)
    plt.title(f'busines_filling Distribution for {model}', fontsize=15)
    plt.xlabel('busines_filling')
    plt.ylabel('quantity')

    plt.subplot(122)
    sns.boxplot(section.values, color=colors[1])
    plt.title(f'busines_filling Distribution for {model}', fontsize=15)
    plt.xlabel('busines_filling')
    plt.show()
# Out:
# 'Sukhoi Superjet-100'
# 1.000000    34
# 0.833333     9
# 0.916667     8
# 0.750000     5
# 0.666667     2
# 0.500000     1
# Name: busines_filling, dtype: int64
# 'Boeing 737-300'
# 0.916667    21
# 1.000000    15
# 0.833333    11
# 0.750000     6
# 0.666667     4
# 0.583333     1
# 0.500000     1
# Name: busines_filling, dtype: int64

# %%
sns.jointplot(data=data, y='busines_filling', x="revenue", color=colors[0])
plt.show()

# %%
sns.jointplot(data=data, y='econom_filling', x="revenue", color=colors[0])
plt.show()

# %% [markdown]
# Гипотеза о заполняемости бизнес класса частично подтверждается. Чаще всего эти места заполнены.
#
# А вот заполнение мест эконом класса для Боинга, чаще всего 83%, тогда как для Сухого чаще 100%.
#
# Стоит отметить, что прибыль линейно зависит отзаполнения салона независимо от класса.

# %% [markdown]
# ### flight_delay
#
# Задержка вылета. Судя по коэффициенту корреляции Пирсона, не влияет на прибыль.
# Посмотрим на распределение.

# %%
data.flight_delay.value_counts()
# Out:
# 3.0      31
# 2.0      24
# 1.0      17
# 4.0      14
# 5.0      11
# 0.0       6
# 6.0       5
# 7.0       4
# 8.0       3
# 162.0     1
# 197.0     1
# 207.0     1
# Name: flight_delay, dtype: int64

# %%
sns.jointplot(data=data, y="flight_delay", x="revenue", color=colors[0])
plt.show()

# %% [markdown]
# Задержка вылета на прибыль не влияет.
# Значит штрафные санкции за задержку не взымаются.

# %% [markdown]
# Исходя из данных корреляцииследует что:
#
# * чем дольше по времени длится полёт, тем прибыльнее рейс;
# * чем больше расход топлива, тем больше прибыль;
# * чем больше максимальная дальность полёта воздушного судна, тем больше прибыль;
# * чем больше расходы, в данном случае связанные с затратами на топливо, тем больше прибыль.
#
# __Однако__ в датасете у нас только __два направления__, а значит длительность полёта среди рейсов внутри одного направления не должна сильно различаться, что в свою очередь не должно сильно сказываться на прибыльности рейсов внутри одного направления.
#
# Так-же на ряду с направлениями, есть только две модели самолётов, которые привязаны каждая к своему направлению. Значит максимальная дальность полёта и расход топлива тоже не могут повлиять на прибыль внутри одного направления, т.к. это просто характеристики самолёта.
#
# Вместе с тем, количество израсходованного топлива и сами расходы, связанные с покупкой, запракой и хранением топлива тоже не должны сильно повлиять на прибыль внутри одного направления, т.к. расход топлива д.б. сопостоавимым.
#
# Проверим эти гипотезы, разбив датасет по направлениям.

# %%
for city in data.city_arrival.unique():
    part = data.loc[data['city_arrival'] == city, ['revenue', 'fuel_costs', 'flight_duration_minutes']]
    plt.figure(figsize=(15, 15))
    plt.subplot(121)
    sns.heatmap(part.corr(), annot=True)
    plt.gcf().set_size_inches(15, 5)
    plt.title(f'Pirson correlation for {city}', fontsize=15)
    sns.jointplot(data=part, y="fuel_costs", x="revenue", color=colors[0], kind="reg")
    sns.jointplot(data=part, y="flight_duration_minutes", x="revenue", color=colors[1], kind="reg")
    plt.show()

# %% [markdown]
# Действительно, внутри одного направления затраты на топливо и длительность полёта слабо влияют на прибыль.

# %%
data.head()
# Out:
#    flight_id city_departure city_arrival           model  range  \
# 0     136119          Anapa       Moscow  Boeing 737-300   4200
# 1     136120          Anapa       Moscow  Boeing 737-300   4200
# 2     136122          Anapa       Moscow  Boeing 737-300   4200
# 3     136130          Anapa       Moscow  Boeing 737-300   4200
# 4     136131          Anapa       Moscow  Boeing 737-300   4200
#
#    total_cost_of_tickets  flight_duration_minutes       scheduled_departure  \
# 0              1653000.0                      101 2017-01-03 10:05:00+00:00
# 1              1605400.0                       99 2017-02-24 10:05:00+00:00
# 2              1431000.0                      100 2017-01-08 10:05:00+00:00
# 3              1556600.0                       99 2017-02-13 10:05:00+00:00
# 4              1812800.0                       99 2017-01-28 10:05:00+00:00
#
#    number_of_tickets  n_busines  common_n_b_class_seats  n_economy  \
# ...

# %% [markdown]
# # промежуточные выводы
#
# * На прибыль более всего влияет заполняемость салона.
# * Не смотря на то, что затраты на топливо для модели самолёта Сухой суперджет 100 ниже, чем для Боинг 737-300, максимальная прибыль для Сухого почти в два раза ниже, чем минимальная для Боинга. Вероятно, это связано с дальностью полёта, по-прямой до Москвы почти в два раза дальше чем до Белгорода, да и длительность полёта в Москву в два раза больше, чем длительность полёта в Белгород.
# * Нет данных для направления Новокузнецк. Они могли бы пролить свет на вопрос о расстоянии и прибыли.
# * Недостаточно данных для расчёта реальных затрат. Не учтены зарплата экипажа и работников аэропорта, амортизация самолёта, и аэропортов, расходы на питание пасажиров и т.д.
#
# ЗАДАЧА
#
# Выяснить, от каких самых малоприбыльных рейсов из Анапы мы можем отказаться в зимнее время.

# %% [markdown]
# # Дополнительное задание.
# → Шаг 1. Укажите номера рейсов, которые вы предлагаете убрать. Укажите предполагаемую прибыльность этих рейсов и среднюю прибыльность всех рейсов.
#
# → Шаг 2. Опишите, как вы проводили аналитику, какие данные были использованы для оценки доходности рейса и расходов на них.

# %%
part = data.loc[data['city_arrival'] == 'Moscow', ['revenue', 'flight_id']]
sns.jointplot(data=part, y="flight_id", x="revenue", color=colors[0])
plt.show()

# %%
part = data.loc[data['city_arrival'] == 'Belgorod', ['revenue', 'flight_id']]
sns.jointplot(data=part, y="flight_id", x="revenue", color=colors[0])
plt.show()

# %% [markdown]
# ### Шаг 1. Укажите номера рейсов, которые вы предлагаете убрать.
#
# Для ответа на этот вопрос воспользуемся негласной формулой расчёта стоимости билета, а именно -
# цена билетов формируется из расчёта заполнения 70% салона.
# Значит выберем те рейсы, заполняемость салона которых ниже 70%

# %%
data['total_filling'] = data.number_of_tickets / (data.common_n_b_class_seats + data.common_n_e_class_seats)
data[data.total_filling < 0.7]
# Out:
#     flight_id city_departure city_arrival                model  range  \
# 77     136642          Anapa     Belgorod  Sukhoi Superjet-100   3000
#
#     total_cost_of_tickets  flight_duration_minutes       scheduled_departure  \
# 77               531000.0                       49 2017-01-30 09:25:00+00:00
#
#     number_of_tickets  n_busines  common_n_b_class_seats  n_economy  \
# 77                 64       10.0                      12       54.0
#
#     common_n_e_class_seats  flight_delay  fuel_price  fuel_consumption  \
# 77                      85           3.0       35.59         28.333333
#
#     fuel_costs     revenue day_of_week  month  econom_filling  \
# 77   54499.025  476500.975      Monday      1        0.635294
#
#     busines_filling  total_filling
# 77         0.833333       0.659794

# %% [markdown]
# Таким образом предлагается исключить только один рейс с номером 136642.

# %% [markdown]
# ### Укажите предполагаемую прибыльность этих рейсов и среднюю прибыльность всех рейсов.
#
# Предполагаемая прибыльность рейса 136642 отрицательная. Хотя в текущем датасете она положительная, но тут не учтены многие показатели указанные в промежуточных выводах.

# %%
data.revenue.mean()
# Out:
# 1066746.7793079107

# %% [markdown]
# Средняя прибыльность всех рейсов может составить __1066746__ рублей __78__ копеек. Без учёта очень многих издержек производства.

# %% [markdown]
# ### Шаг 2. Опишите, как вы проводили аналитику, какие данные были использованы для оценки доходности рейса и расходов на них.

# %% [markdown]
# К моему сожалению об условиях дополнительного задания я узнал очень поздно, моя вина, поэтому переделывть EDA времени уже не осталсь, нужно ещё презентацию сделать.
#
# Какие данные были использованы для расчёта прибыли подробно расписано в разделе после заголовка `flight_duration_minutes`.
#
# Вся аналитика проводилась последовательно, исходя из выбранных мною данных. Данные выбирались непрофессионально, т.к. я очень далёк от авиции, выбор колонок был обусловлен тем, что мне казалось могло бы повлиять на прибыль исходя из логики, основаной на скудных знаниях в предметной области.
